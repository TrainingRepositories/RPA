# %% [markdown]
# # Python BuiltIn Functions & Keywords
#
# [notion](https://loud-iberis-61b.notion.site/BuiltIn-Functions-Keywords-12541d33cda980b1970adb69d9ff1a6c?pvs=4) |
#
# Created by Abdulwahab Alanazi
#
# [LinkedIn](http://linkedin.com/in/abdulwahabdev) | [GitHub](https://github.com/AbdulwahabDev)
